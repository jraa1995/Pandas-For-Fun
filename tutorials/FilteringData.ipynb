# %% [markdown]
# ## Filtering Data using Pandas
# To filter, we can do: <br><br>
# => `df[df['column_of_interest'] =><= != # or "text"]['column_name','column_name]`

# %%
import pandas as pd

# %%
bios = pd.read_csv('../data/bios.csv')

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
# lets filter by height, and grab specific columns such as name, height
bios.loc[bios['height_cm'] > 215, ['name', 'height_cm']]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# 107408       Peter John Ramos      219.0
# 112312           Stanko Barać      217.0
# 112332    Andreas Glyniadakis      216.0
# 112337          Hamed Haddadi      218.0
# 118663         Timofey Mozgov      216.0
# 118676        Dmitry Musersky      219.0
# 120266           Zhang Zhaoxu      221.0
# 121694            Salah Mejri      216.0
# 123850         Tyson Chandler      216.0
# 130460               Li Muhao      218.0
# 130461                Zhou Qi      217.0
# 138671          Ondřej Balvín      216.0
# 139365         Moustapha Fall      218.0

# %%
# lets use a short hand syntax
bios[bios['height_cm'] > 215][['name', 'height_cm']]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# 107408       Peter John Ramos      219.0
# 112312           Stanko Barać      217.0
# 112332    Andreas Glyniadakis      216.0
# 112337          Hamed Haddadi      218.0
# 118663         Timofey Mozgov      216.0
# 118676        Dmitry Musersky      219.0
# 120266           Zhang Zhaoxu      221.0
# 121694            Salah Mejri      216.0
# 123850         Tyson Chandler      216.0
# 130460               Li Muhao      218.0
# 130461                Zhou Qi      217.0
# 138671          Ondřej Balvín      216.0
# 139365         Moustapha Fall      218.0

# %%
# what if we want to combine things and have multiple conditions, we can add parenthesis & char
bios[(bios['height_cm'] > 215) & (bios['weight_kg'] > 100)][['name', 'height_cm', 'weight_kg']]
# Out:
#                          name  height_cm  weight_kg
# 5089       Viktor Pankrashkin      220.0      112.0
# 5583     Paulinho Villas Boas      217.0      106.0
# 5673           Gunther Behnke      221.0      114.0
# 5716                 Uwe Blab      218.0      110.0
# 5781           Tommy Burleson      223.0      102.0
# 6223              Lars Hansen      216.0      105.0
# 6270              Hu Zhangbao      216.0      135.0
# 6409         Sergey Kovalenko      216.0      111.0
# 6420            Jānis Krūmiņš      218.0      141.0
# 6504              Luc Longley      220.0      135.0
# 6722         Shaquille O'Neal      216.0      137.0
# 6937           David Robinson      216.0      107.0
# 6978          Arvydas Sabonis      223.0      122.0
# 7074           Paulo da Silva      217.0      106.0
# 7188       Vladimir Tkachenko      220.0      110.0
# 7281         Stojko Vranković      217.0      115.0
# 7376      Eurelijus Žukauskas      218.0      115.0
# 52608         Aleksey Kazakov      217.0      102.0
# 82100           Frédéric Weis      218.0      110.0
# 89070                Yao Ming      226.0      141.0
# 89075          Roberto Dueñas      221.0      137.0
# 107408       Peter John Ramos      219.0      113.0
# 112312           Stanko Barać      217.0      110.0
# 112332    Andreas Glyniadakis      216.0      115.0
# 112337          Hamed Haddadi      218.0      110.0
# 118663         Timofey Mozgov      216.0      113.0
# 118676        Dmitry Musersky      219.0      104.0
# 120266           Zhang Zhaoxu      221.0      110.0
# 121694            Salah Mejri      216.0      110.0
# 123850         Tyson Chandler      216.0      107.0
# 130460               Li Muhao      218.0      115.0
# 138671          Ondřej Balvín      216.0      107.0

# %%
# or country
bios[(bios['height_cm'] > 215) & (bios['born_country'] == "USA")][['name', 'born_country', 'height_cm', 'weight_kg']]
# Out:
#                     name born_country  height_cm  weight_kg
# 5781      Tommy Burleson          USA      223.0      102.0
# 6722    Shaquille O'Neal          USA      216.0      137.0
# 6937      David Robinson          USA      216.0      107.0
# 123850    Tyson Chandler          USA      216.0      107.0

# %% [markdown]
# ## Filtering Data | String Operations, Regular Expressions (Regex)
# Here, we will be using string operations, regular expressions to filter our data

# %%
# we want to filter our data with the names that begin with "Keith" || It is case sensitive, so you have to be sure that capitalize 
# but we could also use the argument case=False to allow it to run even with lowercaps
bios[bios['name'].str.contains("keith", case=False)]
# Out:
#         athlete_id                  name   born_date         born_city  \
# 1897          1907          Keith Hanlon  1966-09-01               NaN
# 3505          3517         Keith Wallace  1961-03-29           Preston
# 6228          6255         Keith Hartley  1940-10-15         Vancouver
# 8898          8946           Keith Mwila  1966-01-01               NaN
# 12053        12118          Keith Hervey  1898-11-03            Fulham
# ...            ...                   ...         ...               ...
# 109900      111105     Keith Cumberpatch  1927-08-25      Christchurch
# 115973      117348       Keith Sanderson  1975-02-02          Plymouth
# 117676      119195          Duncan Keith  1983-07-16          Winnipeg
# 122121      124176        Keith Ferguson  1979-09-07              Sale
# 127310      129749  Tracy Keith-Matchitt  1990-03-30  Palmerston North
#
#               born_region born_country            NOC  height_cm  weight_kg  \
# 1897                  NaN          NaN        Ireland        NaN        NaN
# 3505              England          GBR  Great Britain      165.0       51.0
# 6228     British Columbia          CAN         Canada      200.0       85.0
# 8898                  NaN          NaN         Zambia        NaN        NaN
# 12053             England          GBR  Great Britain        NaN        NaN
# ...                   ...          ...            ...        ...        ...
# 109900         Canterbury          NZL    New Zealand        NaN        NaN
# 115973      Massachusetts          USA  United States      183.0       95.0
# 117676           Manitoba          CAN         Canada      185.0       88.0
# 122121           Victoria          AUS      Australia      176.0       78.0
# 127310  Manawatu-Wanganui          NZL   Cook Islands      167.0       60.0
#
#          died_date
# 1897           NaN
# 3505    1999-12-31
# 6228           NaN
# 8898    1993-01-09
# 12053   1973-02-22
# ...            ...
# 109900  2013-11-15
# 115973         NaN
# 117676         NaN
# 122121         NaN
# 127310         NaN
#
# [70 rows x 10 columns]

# %%
# what if you need it to contain "keith" or "patrick"?
# we can use the "|" to create an OR operator
bios[bios['name'].str.contains("keith|patrick", case=False)]
# Out:
#         athlete_id               name   born_date              born_city  \
# 6                7      Patrick Chila  1969-11-27            Ris-Orangis
# 119            120   Patrick Wheatley  1899-01-20                Vryheid
# 319            320  Patrick De Koning  1961-04-23            Dendermonde
# 1897          1907       Keith Hanlon  1966-09-01                    NaN
# 2115          2125       Patrick Jopp  1962-01-08                    NaN
# ...            ...                ...         ...                    ...
# 143975      147633  Patrick Chinyemba  2001-01-03                    NaN
# 144172      147850      Patrick Jakob  1996-10-17  Sankt Johann in Tirol
# 144547      148239  Patrick Galbraith  1986-03-11              Haderslev
# 144565      148257    Patrick Russell  1993-01-04               Gentofte
# 145435      149158  Patrick Gasienica  1998-11-28                McHenry
#
#             born_region born_country            NOC  height_cm  weight_kg  \
# 6               Essonne          FRA         France      180.0       73.0
# 119       KwaZulu-Natal          RSA  Great Britain        NaN        NaN
# 319     Oost-Vlaanderen          BEL        Belgium      178.0       92.0
# 1897                NaN          NaN        Ireland        NaN        NaN
# 2115                NaN          NaN    Switzerland      176.0       67.0
# ...                 ...          ...            ...        ...        ...
# 143975              NaN          NaN         Zambia        NaN        NaN
# 144172            Tirol          AUT        Austria        NaN        NaN
# 144547       Syddanmark          DEN        Denmark        NaN        NaN
# 144565      Hovedstaden          DEN        Denmark      186.0       93.0
# 145435         Illinois          USA  United States        NaN        NaN
#
#          died_date
# 6              NaN
# 119     1967-11-05
# 319            NaN
# 1897           NaN
# 2115           NaN
# ...            ...
# 143975         NaN
# 144172         NaN
# 144547         NaN
# 144565         NaN
# 145435  2023-06-12
#
# [303 rows x 10 columns]

# %% [markdown]
# ## Filtering Data | Regular Expressions
# These can be very powerful in manipulating textual data. Here are some examples we can take a look at: <br><br>
#
# **1. Find athletes born in citites that start with a vowel**<br>
# `vowel_cities = bios[bios['born_city'].str.contains(r'^[AEIOUaeiou'], na=False)]`

# %%
vowel_cities = bios[bios['born_city'].str.contains(r'^[AEIOUaeiou]', na=False)]
vowel_cities
# Out:
#         athlete_id                     name   born_date       born_city  \
# 5                6        Nicolas Chatelain  1970-01-13          Amiens
# 10              11  Élie, Comte de Lastours  1874-08-12         Orgeval
# 17              18     Jean-Philippe Gatien  1968-10-16            Alès
# 35              36          Étienne Thobois  1967-09-20          Amiens
# 40              41           Julie Bradbury  1967-02-12          Oxford
# ...            ...                      ...         ...             ...
# 145395      149118             Abbey Murphy  2002-04-14  Evergreen Park
# 145398      149121          Grace Zumwinkle  1999-04-23       Excelsior
# 145405      149128             Brian Cooper  1993-11-01       Anchorage
# 145418      149141              Nick Perbix  1998-06-15       Elk River
# 145427      149150            Jared Shumate  1999-03-06         Atlanta
#
#        born_region born_country            NOC  height_cm  weight_kg  \
# 5            Somme          FRA         France      181.0       70.0
# 10        Yvelines          FRA         France        NaN        NaN
# 17            Gard          FRA         France      178.0       73.0
# 35           Somme          FRA         France      186.0       78.0
# 40         England          GBR  Great Britain      175.0       64.0
# ...            ...          ...            ...        ...        ...
# 145395    Illinois          USA  United States        NaN        NaN
# 145398   Minnesota          USA  United States        NaN        NaN
# 145405      Alaska          USA  United States        NaN        NaN
# 145418   Minnesota          USA  United States        NaN        NaN
# 145427     Georgia          USA  United States        NaN        NaN
#
#          died_date
# 5              NaN
# 10      1932-11-18
# 17             NaN
# 35             NaN
# 40             NaN
# ...            ...
# 145395         NaN
# 145398         NaN
# 145405         NaN
# 145418         NaN
# 145427         NaN
#
# [12968 rows x 10 columns]

# %% [markdown]
# **2. Find athletes with names that cointain exactly two vowels**<br>
# `name_w_two_vowels = bios[bios['name'].str.contains(r'^[AEIOUaeiou]*[AEIOUaeiou][AEIOUaeiou][^AEIOUaeiou]*[AEIOUaeiou][^AEIOUaeiou]*$', na=False)]`<br><br>
#
# Lets break this regex down. <br><br>
# `^[AEIOUaeiou]*`<br>
# `^` -> ensures that we start from the beginning of the string<br>
# `[AEIOUaeiou]*` -> matches zero or more vowels at the start<br>
# `[AEIOUaeiou][AEIOUaeiou]` -> this ensures that at least one vowel pair exists, it can match two consecutive vowels like "ee" in Reese or "ai" in laila<br>
# `[^AEIOUaeiou]*` -> matches zero or more consononats after the first vowel pair. this allows a gap between the first and second vowel occurrences<br>
# `[^AEIOUaeiou]*$` -> ensures that everything after the last vowel is only consonants<br>
# `$` -> marks the end of the string, ensuring no additional vowels appear later<br>

# %%
name_w_two_vowels = bios[bios['name'].str.contains(r'^[AEIOUaeiou]*[AEIOUaeiou][AEIOUaeiou][^AEIOUaeiou]*[AEIOUaeiou][^AEIOUaeiou]*$', na=False)]
name_w_two_vowels
# Out:
#         athlete_id           name   born_date              born_city  \
# 1148          1155      Ian Clyde  1956-05-15                 Verdun
# 5771          5794     Earl Brown  1952-06-23                    NaN
# 7875          7916    Ion Györffi  1949-11-25  București (Bucharest)
# 12712        12782      Ian Stark  1954-02-22             Galashiels
# 14285        14379     Aimé Fritz  1884-04-23                Saverne
# 16410        16526      Ian Scott  1915-01-09                    NaN
# 17405        17525       Ian Dick  1926-08-30                Boulder
# 17667        17788       Ian Bird  1970-03-18              Vancouver
# 19779        19918       Ian Kerr  1935-02-10              Kilbirnie
# 23073        23247       Ioan Pop  1954-10-24            Cluj-Napoca
# 26915        27110   Ion Pîrcălab  1941-11-05  București (Bucharest)
# 30541        30776    Eilert Bøhm  1900-07-17                   Moss
# 30615        30851    Einar Strøm  1885-03-17              Haugesund
# 35097        35370      Ian Clubb  1955-01-01                    NaN
# 35262        35536      Ian Tutty  1937-03-07                    NaN
# 37111        37406     Ian McNuff  1957-03-10                    NaN
# 37211        37507      Ian Welsh  1933-03-10             Birmingham
# 38965        39268     Ian Wright  1961-12-09               Wanganui
# 39289        39594      Ioan Snep  1966-07-12           Negrești-Oaș
# 39305        39610     Ion Vlăduț  1930-03-03                    NaN
# 44823        45165      Ian Brown  1965-08-14                    NaN
# 46853        47202      Ian Black  1941-06-27              Inverness
# 47960        48312  Earl McCarthy  1969-02-08                    NaN
# 53042        53417      Ian Mills  1945-01-22                    NaN
# 56924        57329    August Thys  1895-11-15    Antwerpen (Antwerp)
# 57100        57506    Aubert Côté  1881-03-22               Beaumont
# 59382        59808       Ion Păun  1951-02-17                Drăganu
# 59406        59832    Iosif Töjär  1911-11-29                 Oradea
# 61022        61464      Ian Brown  1954-04-04                    NaN
# 63037        63507       Ian Ruff  1946-12-16                    NaN
# 64900        65390       Ian Gray  1963-12-16                    NaN
# 68388        68905       Ian Boyd  1933-12-08                  Epsom
# 70960        71493   Ailish Smyth  1958-09-18                    NaN
# 74644        75217      Ion Söter  1927-05-16              Timișoara
# 77506        78097      Earl Bell  1955-08-25                  Ancón
# 77769        78360       Earl Eby  1894-11-18                 Aurora
# 85303        85983      Ion Gavăț  1900-07-19              Tâmboeşti
# 89463        90180      Ian Wynne  1973-11-30              Sevenoaks
# 92101        92835     Iain Percy  1976-03-21            Southampton
# 94929        95696  Eilert Määttä  1935-09-22                    NaN
# 97220        98005    Aivis Švāns  1969-05-02                  Cēsis
# 97504        98291       Ian Todd  1947-06-26             Darlington
# 98514        99310    Einar Østby  1935-09-17                    NaN
# 104688      105710      Ian Waltz  1977-04-15             Post Falls
# 107166      108289     Ian Syster  1976-01-20          Prince Albert
# 107923      109063     Ian Symons  1980-05-14               Chinhoyi
# 108978      110155     Euan Byers  1974-07-30               Dumfries
# 110226      111435       Ian Hogg  1989-12-15               Auckland
# 122300      124369    Ieuan Lloyd  1993-07-09                Cardiff
# 128884      131463      Aury Cruz  1982-01-10               New York
# 130373      133057    Iain Smythe  1985-06-02              Vancouver
# 140086      143583         Ian Ho  1997-04-25                    NaN
#
#               born_region born_country               NOC  height_cm  \
# 1148               Québec          CAN            Canada      162.0
# 5771                  NaN          NaN       Puerto Rico      208.0
# 7875            București          ROU           Romania      180.0
# 12712            Scotland          GBR     Great Britain      177.0
# 14285            Bas-Rhin          FRA     United States        NaN
# 16410                 NaN          NaN     Great Britain        NaN
# 17405   Western Australia          AUS         Australia        NaN
# 17667    British Columbia          CAN            Canada      187.0
# 19779            Scotland          GBR       New Zealand      183.0
# 23073                Cluj          ROU           Romania      176.0
# 26915           București          ROU           Romania      173.0
# 30541               Viken          NOR            Norway        NaN
# 30615            Rogaland          NOR            Norway        NaN
# 35097                 NaN          NaN         Australia      193.0
# 35262                 NaN          NaN         Australia      180.0
# 37111                 NaN          NaN     Great Britain      183.0
# 37211             England          GBR     Great Britain        NaN
# 38965   Manawatu-Wanganui          NZL       New Zealand      189.0
# 39289           Satu Mare          ROU           Romania      192.0
# 39305                 NaN          NaN           Romania        NaN
# 44823                 NaN          NaN         Australia      186.0
# 46853            Scotland          GBR     Great Britain      175.0
# 47960                 NaN          NaN           Ireland        NaN
# 53042                 NaN          NaN         Australia      188.0
# 56924           Antwerpen          BEL           Belgium        NaN
# 57100              Québec          CAN            Canada      160.0
# 59382               Argeș          ROU           Romania      165.0
# 59406               Bihor          ROU           Romania        NaN
# 61022                 NaN          NaN         Australia      184.0
# 63037                 NaN          NaN         Australia      170.0
# 64900                 NaN          NaN            Belize      187.0
# 68388             England          GBR     Great Britain      174.0
# 70960                 NaN          NaN           Ireland      171.0
# 74644               Timiș          ROU           Romania      186.0
# 77506              Panamá          PAN     United States      191.0
# 77769            Illinois          USA     United States      179.0
# 85303             Vrancea          ROU           Romania        NaN
# 89463             England          GBR     Great Britain      184.0
# 92101             England          GBR     Great Britain      185.0
# 94929                 NaN          NaN            Sweden        NaN
# 97220         Cēsu novads          LAT            Latvia      183.0
# 97504             England          GBR     Great Britain      183.0
# 98514                 NaN          NaN            Norway        NaN
# 104688              Idaho          USA     United States      186.0
# 107166       Western Cape          RSA      South Africa      175.0
# 107923   Mashonaland West          ZIM      South Africa      178.0
# 108978           Scotland          GBR     Great Britain      175.0
# 110226           Auckland          NZL       New Zealand      180.0
# 122300              Wales          GBR     Great Britain      194.0
# 128884           New York          USA       Puerto Rico      180.0
# 130373   British Columbia          CAN            Canada      180.0
# 140086                NaN          NaN  Hong Kong, China        NaN
#
#         weight_kg   died_date
# 1148         51.0         NaN
# 5771        100.0         NaN
# 7875         71.0         NaN
# 12712        75.0         NaN
# 14285         NaN  1950-01-28
# 16410         NaN  1980-05-15
# 17405         NaN  2012-09-05
# 17667        81.0         NaN
# 19779        70.0         NaN
# 23073        75.0         NaN
# 26915        67.0         NaN
# 30541         NaN  1982-02-01
# 30615         NaN  1964-09-26
# 35097        89.0         NaN
# 35262        73.0         NaN
# 37111        85.0         NaN
# 37211         NaN         NaN
# 38965        90.0         NaN
# 39289        94.0         NaN
# 39305         NaN         NaN
# 44823        74.0         NaN
# 46853        72.0         NaN
# 47960         NaN         NaN
# 53042        84.0         NaN
# 56924         NaN  1959-09-11
# 57100        52.0  1938-05-27
# 59382        68.0         NaN
# 59406         NaN  1992-01-01
# 61022        70.0         NaN
# 63037        71.0         NaN
# 64900        64.0         NaN
# 68388        58.0         NaN
# 70960        64.0         NaN
# 74644        70.0  1987-09-26
# 77506        77.0         NaN
# 77769        60.0  1970-12-14
# 85303         NaN  1978-06-18
# 89463        81.0         NaN
# 92101        92.0         NaN
# 94929         NaN  2011-05-07
# 97220        82.0         NaN
# 97504        72.0         NaN
# 98514         NaN  2022-04-03
# 104688      122.0         NaN
# 107166       55.0  2004-12-25
# 107923       76.0         NaN
# 108978       79.0         NaN
# 110226       68.0         NaN
# 122300       91.0         NaN
# 128884       63.0         NaN
# 130373       77.0         NaN
# 140086        NaN         NaN

# %% [markdown]
# **3. Find athletes with names that have repeated consecutive letters (e.g., "Aaron", "Emmett")**<br>
# `repeated_letters = bios[bios['name'].str.contains(r'(.)\1)', na=False)]`<br><br>

# %%
repeated_letters = bios[bios['name'].str.contains(r'(.)\1', na=False)]
repeated_letters
# Out:
# C:\Users\justi\AppData\Local\Temp\ipykernel_19112\479376446.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   repeated_letters = bios[bios['name'].str.contains(r'(.)\1', na=False)]
#         athlete_id                  name   born_date          born_city  \
# 9               10    Guy de la Chapelle  1868-07-16  Farges-Allichamps
# 13              14        Étienne Durand         NaN                NaN
# 17              18  Jean-Philippe Gatien  1968-10-16               Alès
# 20              21         Pierre Hirsch  1900-11-08           Paris Ie
# 28              29       Albert Lippmann         NaN                NaN
# ...            ...                   ...         ...                ...
# 145474      149201     Nadine Hofstetter  1994-10-21             Romoos
# 145488      149215          Shakeel John  2001-07-30         Mount Hope
# 145491      149218         Matthew Wepke  1989-12-05                NaN
# 145498      149225        André Foussard  1899-05-19              Niort
# 145499      149814         Bill Phillips  1913-07-15       Dulwich Hill
#
#             born_region born_country                  NOC  height_cm  \
# 9                  Cher          FRA               France        NaN
# 13                  NaN          NaN               France        NaN
# 17                 Gard          FRA               France      178.0
# 20                Paris          FRA               France        NaN
# 28                  NaN          NaN               France        NaN
# ...                 ...          ...                  ...        ...
# 145474           Luzern          SUI          Switzerland      164.0
# 145488  Tunapuna-Piarco          TTO  Trinidad and Tobago        NaN
# 145491              NaN          NaN              Jamaica        NaN
# 145498      Deux-Sèvres          FRA               France      166.0
# 145499  New South Wales          AUS            Australia        NaN
#
#         weight_kg   died_date
# 9             NaN  1923-08-27
# 13            NaN         NaN
# 17           73.0         NaN
# 20            NaN  1942-04-19
# 28            NaN         NaN
# ...           ...         ...
# 145474       68.0         NaN
# 145488        NaN         NaN
# 145491        NaN         NaN
# 145498        NaN  1986-03-18
# 145499        NaN  2003-10-20
#
# [38860 rows x 10 columns]

# %% [markdown]
# **4. Find athletes with names ending in 'son' or 'sen'**<br>
# `son_sen_names = bios[bios['name'].str.contains(r'son$|sen$', case=False, na=False)]`

# %%
son_sen_names = bios[bios['name'].str.contains(r'son$|sen$', case=False, na=False)]
son_sen_names
# Out:
#         athlete_id                name   born_date      born_city  \
# 37              38     Helen Aitchison  1881-12-06     Sunderland
# 92              93         Anne Gibson  1968-10-26       Dumfries
# 107            108      Anders Nielsen  1967-02-24      Cape Town
# 113            114    Julian Robertson  1969-10-09   Peterborough
# 120            121     Chris Wilkinson  1970-01-05    Southampton
# ...            ...                 ...         ...            ...
# 145419      149142      Jake Sanderson  2002-07-08      Whitefish
# 145424      149147  Jonathan Gustafson  1997-03-05        Massena
# 145441      149164        Casey Dawson  2000-08-02      Park City
# 145457      149183      Alix Wilkinson  2000-08-02  Mammoth Lakes
# 145461      149188        Kent Johnson  2002-10-18     Port Moody
#
#              born_region born_country            NOC  height_cm  weight_kg  \
# 37               England          GBR  Great Britain        NaN        NaN
# 92              Scotland          GBR  Great Britain      173.0       70.0
# 107         Western Cape          RSA  Great Britain      173.0       70.0
# 113              England          GBR  Great Britain      182.0       73.0
# 120              England          GBR  Great Britain      180.0       72.0
# ...                  ...          ...            ...        ...        ...
# 145419           Montana          USA  United States        NaN        NaN
# 145424          New York          USA  United States        NaN        NaN
# 145441              Utah          USA  United States        NaN        NaN
# 145457        California          USA  United States        NaN        NaN
# 145461  British Columbia          CAN         Canada      185.0       75.0
#
#          died_date
# 37      1947-05-26
# 92             NaN
# 107     2010-07-29
# 113            NaN
# 120            NaN
# ...            ...
# 145419         NaN
# 145424         NaN
# 145441         NaN
# 145457         NaN
# 145461         NaN
#
# [5799 rows x 10 columns]

# %% [markdown]
# **5. Find athlets born in a year starting with '19'**<br>
# `born_19 = bios[bios['born_date'].str.contains(r'^19', na=False)]`

# %%
born_19 = bios[bios['born_date'].str.contains(r'^19', na=False)]
born_19
# Out:
#         athlete_id                   name   born_date           born_city  \
# 1                2         Arnaud Boetsch  1969-04-01              Meulan
# 5                6      Nicolas Chatelain  1970-01-13              Amiens
# 6                7          Patrick Chila  1969-11-27         Ris-Orangis
# 7                8           Henri Cochet  1901-12-14        Villeurbanne
# 14              15            Damien Éloi  1969-07-04                Vire
# ...            ...                    ...         ...                 ...
# 145492      149219  Carlos García-Ordóñez  1927-04-24  La Habana (Havana)
# 145493      149220     Landysh Falyakhova  1998-08-31    Dva Polya Artash
# 145496      149223    Valeriya Merkusheva  1999-09-20     Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08              Kotlas
# 145499      149814          Bill Phillips  1913-07-15        Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 1                   Yvelines          FRA     France      183.0       76.0
# 5                      Somme          FRA     France      181.0       70.0
# 6                    Essonne          FRA     France      180.0       73.0
# 7                      Rhône          FRA     France        NaN        NaN
# 14                  Calvados          FRA     France      165.0       58.0
# ...                      ...          ...        ...        ...        ...
# 145492   Ciudad de La Habana          CUB       Cuba        NaN        NaN
# 145493  Respublika Tatarstan          RUS        ROC        NaN        NaN
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 1              NaN
# 5              NaN
# 6              NaN
# 7       1987-04-02
# 14             NaN
# ...            ...
# 145492  2019-11-24
# 145493         NaN
# 145496         NaN
# 145497         NaN
# 145499  2003-10-20
#
# [130539 rows x 10 columns]

# %% [markdown]
# ### String - .isin Function
# Here we will test out `.isin` function<br>
#
# An additional Note:<br>
#
# **1. Usage of `[]` Square Brackets**<br>
# - Square brackets are used for indexing and subsetting in pandas<br>
# → `bios[...]` is used to filter the DF bios based on the condition inside the brackets, in our case `born_country`<br>
# → inside `[]`, we have a boolean condition<br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; -..bios['born_country'].isin(["USA", "FRA", "GBR"])...<br>
# → Parenthesis are used to control order of operations (precedence) and group the conditions<br>
# → Inside this condition, we have two logical conditions combined with & (AND): <br  />
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`bios['born_country'].isin(["USA", "FRA", "GBR"]) & (bios['name'].str.startswith("Keith"))`<br>
# → First condition (before the `&`) → checks if born_country is one of the conditions, returns a boolean<br><br>
# → So technically, we can separate the two functions as:<br><br>
# `condition_1 = bios['born_country'].isin(["USA", "FRA","GBR"])` # boolean series<br>
# `condition_2 = bios['name'].str.startswith("Keith")`

# %%
# lets say you want to grab the `born_city` where USA, FRA, GBR and you want "keith" as the name
keith_list = bios[bios['born_country'].isin(["USA", "FRA", "GBR"]) & (bios['name'].str.startswith("Keith"))]
keith_list
# Out:
#         athlete_id                name   born_date             born_city  \
# 3505          3517       Keith Wallace  1961-03-29               Preston
# 12053        12118        Keith Hervey  1898-11-03                Fulham
# 14577        14674      Keith Harrison  1933-03-28            Birmingham
# 16166        16281      Keith Reynolds  1963-12-25              Solihull
# 18734        18862      Keith Sinclair  1945-06-26            Sunderland
# 29897        30123       Keith Langley  1961-06-03             Aldershot
# 34011        34275        Keith Remfry  1947-11-17                Ealing
# 46885        47234        Keith Collin  1937-01-18            Marylebone
# 50929        51288        Keith Carter  1924-08-30                 Akron
# 51185        51544       Keith Russell  1948-01-15                  Mesa
# 52913        53288      Keith Erickson  1944-04-19         San Francisco
# 55317        55712        Keith Boxell  1958-05-06               Clapham
# 57818        58226        Keith Peache  1947-08-10              Lewisham
# 61748        62202       Keith Grogono  1912-11-04             Stratford
# 62620        63086         Keith Musto  1936-01-12              Rochford
# 62678        63144        Keith Notary  1960-01-22        Merritt Island
# 68324        68841         Keith Angus  1943-04-05             Sheffield
# 68472        68989        Keith Cullen  1972-06-13                Ilford
# 68997        69514         Keith Stock  1957-03-18              Woolwich
# 77550        78141       Keith Brantly  1962-05-23  Scott Air Force Base
# 84097        84766  Keith Christiansen  1944-07-14   International Falls
# 94646        95413         Keith Meyer  1938-06-20                Geneva
# 95267        96037        Keith Oliver  1947-10-27             Liverpool
# 96452        97229  Keith Schellenberg  1929-03-13         Middlesbrough
# 97499        98286       Keith Tkachuk  1972-03-28               Melrose
# 98068        98860       Keith Wegeman  1929-08-28                Denver
# 99921       100722        Keith Carney  1970-02-03            Providence
# 115973      117348     Keith Sanderson  1975-02-02              Plymouth
#
#           born_region born_country            NOC  height_cm  weight_kg  \
# 3505          England          GBR  Great Britain      165.0       51.0
# 12053         England          GBR  Great Britain        NaN        NaN
# 14577         England          GBR  Great Britain        NaN        NaN
# 16166         England          GBR  Great Britain      173.0       68.0
# 18734         England          GBR  Great Britain      190.0       79.0
# 29897         England          GBR  Great Britain      173.0       70.0
# 34011         England          GBR  Great Britain      193.0      114.0
# 46885         England          GBR  Great Britain      168.0       63.0
# 50929            Ohio          USA  United States        NaN        NaN
# 51185         Arizona          USA  United States      188.0       73.0
# 52913      California          USA  United States      196.0       86.0
# 55317         England          GBR  Great Britain      170.0       87.0
# 57818         England          GBR  Great Britain      180.0       98.0
# 61748         England          GBR  Great Britain        NaN        NaN
# 62620         England          GBR  Great Britain      174.0       72.0
# 62678         Florida          USA  United States      170.0       66.0
# 68324         England          GBR  Great Britain      170.0       59.0
# 68472         England          GBR  Great Britain      177.0       61.0
# 68997         England          GBR  Great Britain      176.0       73.0
# 77550        Illinois          USA  United States      180.0       64.0
# 84097       Minnesota          USA  United States      165.0       69.0
# 94646        Illinois          USA  United States        NaN        NaN
# 95267         England          GBR  Great Britain      172.0       68.0
# 96452         England          GBR  Great Britain        NaN        NaN
# 97499   Massachusetts          USA  United States      188.0      102.0
# 98068        Colorado          USA  United States        NaN        NaN
# 99921    Rhode Island          USA  United States      188.0       93.0
# 115973  Massachusetts          USA  United States      183.0       95.0
#
#          died_date
# 3505    1999-12-31
# 12053   1973-02-22
# 14577          NaN
# 16166          NaN
# 18734          NaN
# 29897          NaN
# 34011   2015-09-16
# 46885   1991-03-06
# 50929   2013-05-03
# 51185          NaN
# 52913          NaN
# 55317          NaN
# 57818          NaN
# 61748   1999-03-22
# 62620          NaN
# 62678          NaN
# 68324          NaN
# 68472          NaN
# 68997          NaN
# 77550          NaN
# 84097   2018-11-05
# 94646   2010-07-25
# 95267          NaN
# 96452   2019-10-28
# 97499          NaN
# 98068   1974-08-22
# 99921          NaN
# 115973         NaN

# %%
# instead of having to type bios multiple times, we can use a query function
bios.query('born_country == "USA" and born_city == "Seattle"')
# Out:
#         athlete_id                   name   born_date born_city born_region  \
# 11030        11088          David Halpern  1955-08-18   Seattle  Washington
# 12800        12870            Todd Trewin  1958-04-20   Seattle  Washington
# 15476        15583         Scott McKinley  1968-10-15   Seattle  Washington
# 29079        29293            Joyce Tanac  1950-09-27   Seattle  Washington
# 31135        31371        Bill Kuhlemeier  1908-01-14   Seattle  Washington
# ...            ...                    ...         ...       ...         ...
# 133392      136331          Hans Struzyna  1989-03-31   Seattle  Washington
# 135448      138662  Maude Davis Crossland  2003-03-19   Seattle  Washington
# 136993      140229        Jenell Berhorst  2003-12-13   Seattle  Washington
# 143507      147159         Nevin Harrison  2002-06-02   Seattle  Washington
# 145446      149169       Corinne Stoddard  2001-08-15   Seattle  Washington
#
#        born_country            NOC  height_cm  weight_kg   died_date
# 11030           USA  United States      178.0       79.0         NaN
# 12800           USA  United States      180.0       75.0         NaN
# 15476           USA  United States      183.0       75.0         NaN
# 29079           USA  United States      156.0       49.0         NaN
# 31135           USA  United States        NaN        NaN  2001-07-08
# ...             ...            ...        ...        ...         ...
# 133392          USA  United States      188.0       91.0         NaN
# 135448          USA       Colombia        NaN        NaN         NaN
# 136993          USA  United States        NaN        NaN         NaN
# 143507          USA  United States      175.0       73.0         NaN
# 145446          USA  United States        NaN        NaN         NaN
#
# [102 rows x 10 columns]

# %% [markdown]
# ## Adding / Removing Columns

# %%
coffee = pd.read_csv('../warmup-data/coffee.csv')
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
# lets say we want to add a price column, we can easily add a new column by
coffee['price'] = 4.99
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  price
# 0     Monday    Espresso          25   4.99
# 1     Monday       Latte          15   4.99
# 2    Tuesday    Espresso          30   4.99
# 3    Tuesday       Latte          20   4.99
# 4  Wednesday    Espresso          35   4.99

# %%
# what we want to be a bit more specific about the column that we're adding? one price for espresso and one price for latte?
# we would have to use numpy here
import numpy as np

coffee['new_price'] = np.where(coffee['Coffee Type']=='Espresso', 3.99, 5.99)
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  price  new_price
# 0     Monday    Espresso          25   4.99       3.99
# 1     Monday       Latte          15   4.99       5.99
# 2    Tuesday    Espresso          30   4.99       3.99
# 3    Tuesday       Latte          20   4.99       5.99
# 4  Wednesday    Espresso          35   4.99       3.99

# %%
# now we have two prices, `price` and `new_price`. how do we drop one? we have to specify the "column",
# however, we're not truly altering the df, we're just dropping it from the view
coffee.drop(columns=['price'])
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25       3.99
# 1      Monday       Latte          15       5.99
# 2     Tuesday    Espresso          30       3.99
# 3     Tuesday       Latte          20       5.99
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25       5.99
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30       5.99
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35       5.99
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35       5.99
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35       5.99

# %%
# to modify the table, we would have to pass an argument called inplace=True
# coffee.drop(columns=['price'], inplace=True)
coffee
# Out:
#           Day Coffee Type  Units Sold  price  new_price
# 0      Monday    Espresso          25   4.99       3.99
# 1      Monday       Latte          15   4.99       5.99
# 2     Tuesday    Espresso          30   4.99       3.99
# 3     Tuesday       Latte          20   4.99       5.99
# 4   Wednesday    Espresso          35   4.99       3.99
# 5   Wednesday       Latte          25   4.99       5.99
# 6    Thursday    Espresso          40   4.99       3.99
# 7    Thursday       Latte          30   4.99       5.99
# 8      Friday    Espresso          45   4.99       3.99
# 9      Friday       Latte          35   4.99       5.99
# 10   Saturday    Espresso          45   4.99       3.99
# 11   Saturday       Latte          35   4.99       5.99
# 12     Sunday    Espresso          45   4.99       3.99
# 13     Sunday       Latte          35   4.99       5.99

# %%
# if you don't want the coffee db to actually change, you can use 
# .copy(), which will allow pandas to duplicate/copy your dataset and then modify the dataset for your purposes. so
# coffee_new = coffee.copy()
# coffee_new['price'] = 4.99

# %%
# lets add a revenue column where we calculate the revenue from the units sold * new_price
coffee['revenue'] = coffee['Units Sold'] * coffee['new_price']

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  new_price  revenue
# 0      Monday    Espresso          25   4.99       3.99    99.75
# 1      Monday       Latte          15   4.99       5.99    89.85
# 2     Tuesday    Espresso          30   4.99       3.99   119.70
# 3     Tuesday       Latte          20   4.99       5.99   119.80
# 4   Wednesday    Espresso          35   4.99       3.99   139.65
# 5   Wednesday       Latte          25   4.99       5.99   149.75
# 6    Thursday    Espresso          40   4.99       3.99   159.60
# 7    Thursday       Latte          30   4.99       5.99   179.70
# 8      Friday    Espresso          45   4.99       3.99   179.55
# 9      Friday       Latte          35   4.99       5.99   209.65
# 10   Saturday    Espresso          45   4.99       3.99   179.55
# 11   Saturday       Latte          35   4.99       5.99   209.65
# 12     Sunday    Espresso          45   4.99       3.99   179.55
# 13     Sunday       Latte          35   4.99       5.99   209.65

# %%
# lets rename the column new_price to Current price
coffee.rename(columns={'new_price': 'Current price'}, inplace=True)
coffee
# Out:
#           Day Coffee Type  Units Sold  price  Current price  revenue
# 0      Monday    Espresso          25   4.99           3.99    99.75
# 1      Monday       Latte          15   4.99           5.99    89.85
# 2     Tuesday    Espresso          30   4.99           3.99   119.70
# 3     Tuesday       Latte          20   4.99           5.99   119.80
# 4   Wednesday    Espresso          35   4.99           3.99   139.65
# 5   Wednesday       Latte          25   4.99           5.99   149.75
# 6    Thursday    Espresso          40   4.99           3.99   159.60
# 7    Thursday       Latte          30   4.99           5.99   179.70
# 8      Friday    Espresso          45   4.99           3.99   179.55
# 9      Friday       Latte          35   4.99           5.99   209.65
# 10   Saturday    Espresso          45   4.99           3.99   179.55
# 11   Saturday       Latte          35   4.99           5.99   209.65
# 12     Sunday    Espresso          45   4.99           3.99   179.55
# 13     Sunday       Latte          35   4.99           5.99   209.65

# %%
# now lets try the bios dataset
bios_new = bios.copy()

# %%
# lets work on just getting the first name of the 'name'
bios_new['first_name'] = bios_new['name'].str.split(' ').str[0]

# %%
bios_new.query('first_name == "Keith"')
# Out:
#         athlete_id               name   born_date     born_city  \
# 1897          1907       Keith Hanlon  1966-09-01           NaN
# 3505          3517      Keith Wallace  1961-03-29       Preston
# 6228          6255      Keith Hartley  1940-10-15     Vancouver
# 8898          8946        Keith Mwila  1966-01-01           NaN
# 12053        12118       Keith Hervey  1898-11-03        Fulham
# ...            ...                ...         ...           ...
# 99921       100722       Keith Carney  1970-02-03    Providence
# 102227      103168      Keith Beavers  1983-02-09        London
# 109900      111105  Keith Cumberpatch  1927-08-25  Christchurch
# 115973      117348    Keith Sanderson  1975-02-02      Plymouth
# 122121      124176     Keith Ferguson  1979-09-07          Sale
#
#              born_region born_country            NOC  height_cm  weight_kg  \
# 1897                 NaN          NaN        Ireland        NaN        NaN
# 3505             England          GBR  Great Britain      165.0       51.0
# 6228    British Columbia          CAN         Canada      200.0       85.0
# 8898                 NaN          NaN         Zambia        NaN        NaN
# 12053            England          GBR  Great Britain        NaN        NaN
# ...                  ...          ...            ...        ...        ...
# 99921       Rhode Island          USA  United States      188.0       93.0
# 102227           Ontario          CAN         Canada      185.0       75.0
# 109900        Canterbury          NZL    New Zealand        NaN        NaN
# 115973     Massachusetts          USA  United States      183.0       95.0
# 122121          Victoria          AUS      Australia      176.0       78.0
#
#          died_date first_name
# 1897           NaN      Keith
# 3505    1999-12-31      Keith
# 6228           NaN      Keith
# 8898    1993-01-09      Keith
# 12053   1973-02-22      Keith
# ...            ...        ...
# 99921          NaN      Keith
# 102227         NaN      Keith
# 109900  2013-11-15      Keith
# 115973         NaN      Keith
# 122121         NaN      Keith
#
# [64 rows x 11 columns]

# %%
# lets say we just want the birthyear and not the actual dates from the born_date, born date is an object. 
# so we would have to convert a year first, use pd.to_datetime
# if you run bios_new.info(), it will now say that born_datetime is in datetime64 Dtype
bios_new['born_datetime'] = pd.to_datetime(bios_new['born_date'])

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date     first_name born_datetime
# 0       1960-10-02  Jean-François    1886-12-12
# 1              NaN         Arnaud    1969-04-01
# 2       1994-07-17           Jean    1898-08-13
# 3       1978-03-20        Jacques    1895-05-11
# 4       1930-07-25         Albert    1878-04-17
# ...            ...            ...           ...
# 145495         NaN         Polina    2002-01-30
# 145496         NaN       Valeriya    1999-09-20
# 145497         NaN         Yuliya    1998-05-08
# 145498  1986-03-18          André    1899-05-19
# 145499  2003-10-20           Bill    1913-07-15
#
# [145500 rows x 12 columns]

# %%
# with the pd.to_datetime conversion, we can now extract just the year
# we will use .dt, same thing as .str but for a datetime
# you can also use .dt.is_leap_year, or day, etc.
# if you are having problems with the datetime, you can (df['COL'], errors='coerce') which will help fix the issues
# you can also specify the format - (df['COL'], format="%Y-%m-%d"), just to make sure this formats your data correctly.
bios_new['born_year'] = bios_new['born_datetime'].dt.year

# %%
bios_new[['name', 'born_year']]
# Out:
#                          name  born_year
# 0       Jean-François Blanchy     1886.0
# 1              Arnaud Boetsch     1969.0
# 2                Jean Borotra     1898.0
# 3             Jacques Brugnon     1895.0
# 4                Albert Canet     1878.0
# ...                       ...        ...
# 145495      Polina Luchnikova     2002.0
# 145496    Valeriya Merkusheva     1999.0
# 145497        Yuliya Smirnova     1998.0
# 145498         André Foussard     1899.0
# 145499          Bill Phillips     1913.0
#
# [145500 rows x 2 columns]
